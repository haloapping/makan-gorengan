# %% [markdown]
# # Import Modules

# %%
# %matplotlib notebook
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

print(f"Matplotlib version : {matplotlib.__version__}")
print(f"Numpy version      : {np.__version__}")
# Out:
# Matplotlib version : 3.5.1
# Numpy version      : 1.21.5

# %% [markdown]
# # 3D Axes

# %%
fig = plt.figure()
ax = plt.axes(projection="3d")
ax.set(title="3D Axes",
       xlabel="x-axis",
       ylabel="y-axis",
       zlabel="z-axis")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # 3D Line Plot

# %%
z = np.linspace(0, 1, 100)
x = z * np.sin(20 * z)
y = z * np.cos(20 * z)

fig = plt.figure()
ax = plt.axes(projection="3d")

ax.plot(x, y, z, color="green")
ax.set(title="3D Line Plot",
       xlabel="x-axis",
       ylabel="y-axis",
       zlabel="z-axis")

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # 3D Scatter Plot

# %%
z = np.linspace(-5, 0, 1000)
x = z * np.sin(100 * z)
y = z * np.cos(100 * z)

fig = plt.figure()
ax = plt.axes(projection="3d")

ax.scatter(x, y, z, color="gold")
ax.set(title="3D Line Plot",
       xlabel="x-axis",
       ylabel="y-axis",
       zlabel="z-axis")

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
