# %% [markdown]
# # Import Modules

# %%
# %matplotlib notebook

import matplotlib
import matplotlib.pyplot as plt
import numpy as np

print(f"Matplotlib version: {matplotlib.__version__}")
print(f"Numpy version: {np.__version__}")
# Out:
# Matplotlib version: 3.5.1
# Numpy version: 1.21.5

# %% [markdown]
# # Sample Dataset

# %%
n = np.linspace(-3, 3, 100)
x, y = np.meshgrid(n, n)
z = np.sqrt(x**2 + y**2)

# %% [markdown]
# # 3D Wireframe

# %%
fig = plt.figure()

ax = plt.axes(projection="3d")
ax.plot_wireframe(x, y, z, color="orange")
ax.set(title="3D Wireframe",
       xlabel="x-axis",
       ylabel="y-axis",
       zlabel="z-axis")

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="651.3333333333334">

# %% [markdown]
# # 3D Surface Plot

# %%
fig = plt.figure()
ax = plt.axes(projection="3d")

# ax.plot_surface(x, y, z, color="orange")
ax.plot_surface(x, y, z, cmap="viridis")
ax.set(title="3D Surface",
       xlabel="x-axis",
       ylabel="y-axis",
       zlabel="z-axis")

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="975.3333333333334">
